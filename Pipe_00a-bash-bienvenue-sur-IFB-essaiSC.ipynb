# %% [markdown]
# # Formation RNAseq CEA - juin 2024
#
# *Enseignantes: Sandrine Caburet et Claire Vandiedonck.*
#
# Session IFB : 5 CPU + 21 GB de RAM
#
# # Part 0.a : Bienvenue sur l'IFB !

# %% [markdown]
# - 1 - Description d'un ``notebook Jupyter``
# - 2 - Utilisation d'un ``notebook Jupyter``
# - 3 - A vous de jouer !

# %% [markdown]
# Vous voici connecté(e) au serveur *Jupyter Hub de l'IFB* pour réaliser les analyses de données de RNAseq de la semaine.
#
# Ce petit tutoriel a pour but de vous familiariser avec l'usage des notebooks Jupyter dans l'interface **JupyterLab**.
#
# Ce que vous lisez est un **Notebook Jupyter** (extension `.ipynb`), c'est à dire un cahier numérique qui vous permet d'avoir :
# - des infos sous forme de texte, tables, images et liens,
# - des cases pour rentrer des lignes de code,
# - l'affichage des résultat de ces lignes de code (par exemple sous forme de texte, graphique ou de table).
#
# <em>loaded JupyterLab</em> : Version 3.5.0

# %% [markdown]
# ---
# ## Avant d'aller plus loin
#
# <div class="alert alert-block alert-danger"><b>Attention:</b>
# Ne travaillez pas directement sur ce notebook pour ne pas le perdre. Dupliquez-le et renommez-le par exemple en ajoutant vos initiales et travaillez sur cette nouvelle copie. Pour ce faire, dans le panneau de gauche, faites un clic droit sur le fichier et sélectionnez "Duplicate". Puis, toujours dans la colonne de gauche, faites un clic droit sur cette copie et sélectionnez "rename" pour changer le nom. Ouvrez ensuite cette nouvelle version en double cliquant dessus (et refermez la première version pour ne pas confondre les onglets !). Vous êtes prêt(e) à démarrer! <br>
# <br>
# <b>N'oubliez pas de sauvegarder régulièrement votre notebook</b>: <kbd>Ctrl</kbd> + <kbd>S</kbd>. ou en cliquant sur l'icone 💾 en haut à gauche de votre notebook, ou encore dans le Menu du JupyterLab "File puis "Save Notebook"!
# </div>

# %% [markdown]
# ---
# ## *1 - Description d'un notebook Jupyter*

# %% [markdown]
# ### *1.1. Les différents types de cellules*
#
# Dans un notebook Jupyter, il existe 3 sortes de *cellules*, c'est à dire des cases pour entrer des éléments.
# - des cellules de type ***Markdown*** pour avoir simplement du texte, formatable avec quelques signes
# - des cellules de type ***Raw*** pour montrer une commande, mais qui n'est pas exécutable
# - des cellules de type ***Code***, pour contenir des commandes exécutables
#
# Pour info, le type de celule ***Raw*** est en train d'être abandonné par l'écosystème Jupyter pour des raisons de compatibilité, et est donc amené à disparaître. Il vaut donc mieux ne plus l'utiliser.

# %% [markdown]
# Voici un texte dans une cellule *Markdown* :

# %% [markdown]
# Texte dans une cellule

# %% [markdown]
# Voici le même texte dans une cellule *Raw* :

# %% [raw]
# Texte dans une cellule

# %% [markdown]
# Et enfin voici le même texte dans une cellule *Code* :

# %%
Texte dans une cellule

# %% [markdown]
# Vous voyez que le texte d'une cellule *Markdown* apparaît directement sur le fond blanc de la page, qu'une cellule *Raw* forme un encadré gris, et qu'une cellule *Code* a, en plus du cadre gris, deux crochets `[]` à gauche.

# %% [markdown]
# Quand vous faites un clic simple sur une cellule, une barre bleue s'affiche à gauche pour indiquer que cette cellule est **active**.
#
# Pour mieux visualiser les cellules et leur contenu , il vous suffit de double-cliquer dessus.
# Ainsi, si vous double-cliquez ***ici***, vous voyez maintenant ce texte dans son cadre.
#
# Vous pouvez voir que le type de cellule, indiqué en haut du notebook, est *Markdown*.
#
# ### *1.2. Le format Markdown*
#
# Vous voyez aussi 3 exemples de formatage Markdown :
# - en italique en encadrant un mot avec un signe `*` : *Markdown*
# - en gras en encadrant le mot avec 2 signes `**`:  **active**
# - en italique et en gras avec 3 signes `***` de part et d'autre : ***ici***.
#
# Pour revenir à l'affichage simple de cette cellule Mardown, nous devez *l'exécuter*, en appuyant simultanément sur les touche <kbd>Maj</kbd> + <kbd>Enter</kbd>.
# Allez-y !

# %% [markdown]
# Une cellule *Markdown* peut contenir du texte, mais aussi
#     des liens :  https://www.france-bioinformatique.fr/
#
# des images :
#
# ![bioinfo-genial-jupynb-small.png](attachment:54562310-c34c-4914-b359-0a6c817f9741.png)

# %% [markdown]
# et même des tables:
# <center><b>Tableau 1. Exemple de tableau</b> </center>
#
# | SampleID | Genotype | Treatment |
# |----------|----------|-----------|
# | 1        | WT       | untreated |
# | 2        | WT       | untreated |
# | 3        | WT       | untreated |
# | 4        | mutated  | untreated |
# | 5        | mutated  | untreated |
# | 6        | mutated  | untreated |
# | 7        | WT       | treated |
# | 8        | WT       | treated |
# | 9        | WT       | treated |
# | 10       | mutated  | treated |
# | 11       | mutated  | treated |
# | 12       | mutated  | treated |

# %% [markdown]
# Vous pouvez aussi créer des titres et des sous-titres en ajoutant des `#` de manière incrémentale au début d'une ligne:
#
# # Titre principal (avec 1 seul #)
#
# ## Sous-titre 1 (avec 2 ##)
#
# et vous pouvez dès lors vous déplacer dans le notebook grâce à sa **table des matières** ainsi générée, en utilisant l'icône "Table of content" située en 4ème position tout à fait à gauche de la colonne de gauche dans le JupyterLab *(uniquement valable dans les versions >=3 de JupyterLab : vous pouvez vérifier la version dans le menu de JupyterLab: "Help" puis "About jupyter Lab".)*.

# %% [markdown]
# Le format Markdown permet aussi de générer de beaux rapports professionels au format `html`.
#
#
# ***Pour vous aider avec le format Markdown,*** *vous pourrez consulter ces ressources:*
#
# *- Pour faire de jolis rapports html avec Markdown: cliquez sur `Help` dans le menu puis sur `Markdown reference` ou visitez ces liens: [visualization tool1](https://dillinger.io/) ou [visualization tool2](https://stackedit.io/app#) et the [Ultimate guide](https://medium.com/analytics-vidhya/the-ultimate-markdown-guide-for-jupyter-notebook-d5e5abf728fd).*
#
# *- Pour faire directement ***de jolies tables bien formatées***, cet outil est magique: [to draw nice tables](https://www.tablesgenerator.com/markdown_tables )*

# %% [markdown]
# ----
#
# ## *2 - Utilisation d'un notebook Jupyter*
#
# Un notebook Jupyter est flexible, vous pouvez ajouter, modifier, déplacer les cellules à volonté.
#
# Pour **modifier** une cellule, double-cliquez dessus.
#
# Pour **ajouter** une nouvelle cellule, cliquez sur l'icône <kbd>➕</kbd> dans la barre de menus du notebook.
#
# Pour **déplacer** une cellule, vous pouvez la "cliquer-glisser" vers le haut ou vers le bas dans le document.
#
# Pour **copier** une cellule, vous pouvez la sélectionner puis la copier avec l'icône "Copier" (à droite du ciseau) dans le menu du notebook, et la coller ailleurs dans le document. Le classique  <kbd>Ctrl</kbd> <kbd>C</kbd> + <kbd>Ctrl</kbd> <kbd>V</kbd> marche aussi !
#
# Pour **choisir ou modifier le type de cellule**, vous cliquez dessus (la barre bleue s'affiche à gauche de la cellule sélectionnée), et vous choisissez le type voulu dans le menu déroulant dans la barre de menu du notebook.
#
# Pour **exécuter une cellule**, c'est à dire voir son effet :
# - la combinaison de touches <kbd>Ctrl</kbd> + <kbd>Enter</kbd> exécute une cellule.
# - la combinaison de touches <kbd>Shift</kbd> + <kbd>Enter</kbd> exécute une cellule puis passe à la suivante. (En pratique, c'est la plus utile).
# - la combinaison de touches <kbd>Alt</kbd> + <kbd>Enter</kbd> exécute une cellule puis en crée une nouvelle (vide) en dessous.
#
# Vous pouvez aussi utiliser l'icône <kbd>▶︎</kbd> en haut du notebook pour exécuter la cellule sélectionnée ou cliquer dans le menu du JupyterLab sur `Run` et sélectionner dans le menu les cellules que vous souhaiter exécuter.

# %% [markdown]
#
# L'**exécution d'une cellule** va permettre de voir son effet :
# - une cellule *Markdown* prendra son aspect formaté
# - une cellule *Raw* prendra son aspect de cadre gris
# - une cellule *Code* lancera la ou les commande(s) indiquée(s).
#
# **Lorsque vous exécutez une cellule de code**:
# - Si la commande prend du temps, une `*` apparaitra dans les `[]` à gauche de la cellule.
# - Dès que la cellule de code a fini d'être exécutée, une valeur numérique est affichée entre les crochets, correspondant au numéro d'exécution. Par exemple, s'il s'agit de la 10ème cellule de code exécutée, vous verrez `[10]` apparaître. => Ainsi vous pouvez suivre dans quel ordre vos cellules de code ont été exécutées dans un document.
# - Si vous modifiez le contenu d'une cellule de code après l'avoir exécutée, une barre orange s'affiche à gauche de la cellule pour vous alerter *(uniquement valable dans les versions de JupyterLab >=3.1.0 : vous pouvez vérifier la version dans le menu de JupyterLab: "Help" puis "About JupyterLab".)*
# - Dans une cellule de code, toutes les lignes commençant par le symbole `#` ne sont pas exécutées. Cela vous permet d'ajouter aussi des commentaires dans ces cellules.

# %% [markdown]
# ----
#
# ## *3 - A vous de jouer !*
#
#
# #### *3.1. Ajout d'une cellule et mise en forme*
#
#
# <span style="color:blue">  Commencez par ajouter une cellule sous celle-ci. <br>
# Puis mettez-là en *Markdown*, et écrivez un texte partiellement en gras dedans.  </span>

# %% [markdown]
# Ceci vous permettra donc de prendre des notes dans votre notebook de travail, tout au long des séances.

# %% [markdown]
#
# --
#
# #### *3.2. Cellule de code*
#
#
# Ceci est un jupyter notebook en <mark>***bash***</mark>, ce qui signifie que dans une cellule *Code*,  les commandes seront des commandes bash directement interprétables par le serveur. Nous explorerons les commandes basiques de bash dans le prochain notebook.
# Vous pouvez voir le type de noyau (*kernel*) en haut à droite du notebook. Un notebook avec le langage "R" indiquera "R" au lieu de "bash".
#
# <span style="color:blue">  Créez une cellule *Code*. Puis copiez la commande suivante, et exécutez la cellule pour voir le résultat  </span>

# %% [raw]
# # Cette commande permet d'afficher le chemin du dossier de travail : print working directory
#
# pwd

# %% [markdown]
# Vous devriez obtenir un résultat comme :
# `/shared/ifbstore1/home/monlogin` ou `/shared/home/monlogin`
# où `monlogin` est votre nom d'utilisateur sur le serveur de l'IFB.

# %% [markdown]
#
#  --
# #### *3.3. Commandes*
#
# <span style="color:blue">  Dans une nouvelle cellule *Code*, exécutez la commande suivante :  </span>

# %%
# Cette commande liste les éléments dans un dossier. Sans autre précision, elle listera donc les éléments du répertoire dans lequel vous vous situez.

ls

# %% [markdown]
# Vous devriez obtenir une liste d'éléments correspondant à ce que vous voyez dans la colonne à gauche du Jupyter lab.

# %% [markdown]
# Dans le prochain notebook **Pipe_0b-bash_intro-to-bash.ipynb** , vous allez vous familiariser avec un environnement Unix et les commandes bash.

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-success"><b>=> Bravo! 👏👏👏</b><br>
#
# > Vous pouvez **télécharger votre notebook sur votre ordinateur** avec un clic droit sur son nom dans la colonne de gauche et en sélectionnant "download" (l'icone séléctionnée tout à fait à gauche doit être le dossier, en première position, pour voir la liste des fichiers de votre environnement).
#
# > Vous pouvez aussi sauvegarder votre notebook sur votre ordinateur **au format `html`** que vous pourrez ensuite ouvrir avec n'importe quel web browser. Un vrai travail de pro ! Pour ce faire, dans la colonne de gauche, cliquez sur le notebook, puis dans le menu du JupyterLab tout en haut à gauche cliquez sur "File" puis sur "Export notebook as" et sélectionnez "Export notebook to html".  Il sera sauvegardé dans vos "Téléchargements" de votre ordinateur.
#
# > Un dernier point: vous pouvez aussi **importer des fichiers dans votre dossier ou dans votre projet sur le serveur de l'IFB**. En haut de la colonne de gauche, cliquez sur la flèche vers le haut 🔝 et sélectionner le fichier de votre choix depuis votre ordinateur. Vous pourrez ainsi importer dans l'interface JupyterLab un fichier qui ne serait pas présent dans votre environnement. Pour vous entrainer, essayez avec votre notebook sauvegardé au format html. Il apparait alors dans la colonne de gauche. Vous pouvez soit l'ouvrir dans le Jupyter Lab en double cliquant dessus, ou l'ouvrir dans votre web browser en faisant un clic droit puis "Open in a new browser tab".
#     Vous pouvez également faire un simple *glisser-déposer* de votre fichier depuis votre ordi dans la colonne de gauche !
#
# 😁 ***Admirez votre travail !***
#
#
# Maintenant que <u>vous êtes des pros des notebooks Jupyter</u>, nous allons en utiliser dans toutes les séances de cette formation !

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Rappel</b>, dans un notebook jupyter :
#
# - la combinaison de touches <kbd>Ctrl</kbd>+<kbd>Entrée</kbd> exécute une cellule.<br>
# - la combinaison de touches <kbd>Shift</kbd>+<kbd>Entrée</kbd> exécute une cellule puis passe à la suivante. C'est équivalent à cliquer sur l'icone ▶️ dans la barre de menu du notebook.<br>
# - la combinaison de touches <kbd>Alt</kbd>+<kbd>Entrée</kbd> exécute une cellule puis en crée une nouvelle (vide) en dessous.<br>
#
# Pour ajouter une cellule, vous pouvez aussi cliquer sur l'icone ➕ dans la barre de menu du notebook.
# - vous pouvez déplacer les cellules en les glissant pour les réorganiser les unes en-dessous des autres.<br>
# - vous pouvez ajouter des commentaires, soit en commençant la ligne par un "#" dans une cellule de code (ces lignes ne seront pas éxécutées), soit dans une nouvelle céllule de type Markdown.<br>
# - vous sélectionner le type de cellule dans le menu en haut de votre notebbok.<br>
#     - "Code" pour entrer des lignes de commande à éxécuter <br>
#     - "Markdown pour ajouter du texte balisé qui peut être formatté<br>
# - pour modifier une cellule ̀Markdown, double-cliquez dessus<br>
# - attention à la casse des caractères pour les cellules de code<br>
# - évitez les caractères spéciaux dans les cellules de code<br>
#
# <em>
# To make nice html reports with markdown: <a href="https://dillinger.io/" title="dillinger.io">html visualization tool 1</a> or <a href="https://stackedit.io/app#" title="stackedit.io">html visualization tool 2</a>, <a href="https://www.tablesgenerator.com/markdown_tables" title="tablesgenerator.com">to draw nice tables</a>, and the <a href="https://medium.com/analytics-vidhya/the-ultimate-markdown-guide-for-jupyter-notebook-d5e5abf728fd" title="Ultimate guide">Ultimate guide</a>. <br>
# Further reading on JupyterLab notebooks: <a href="https://jupyterlab.readthedocs.io/en/latest/user/notebook.html" title="Jupyter Lab">Jupyter Lab documentation</a>.<br>
# </em>
# </div>

# %% [markdown]
# ____
# Claire Vandiedonck, Sandrine Caburet - 2020-2024
# MAJ : 04/06/2024 by @SCaburet
