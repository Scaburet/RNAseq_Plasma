# %%
if (!requireNamespace("BiocManager", quietly=TRUE))
    install.packages("BiocManager")
BiocManager::install("pcaExplorer")
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# '?repositories' for details
#
# replacement repositories:
#     CRAN: https://cran.r-project.org
#
#
# Bioconductor version 3.12 (BiocManager 1.30.16), R 4.0.3 (2020-10-10)
#
# Installing package(s) 'pcaExplorer'
#
# also installing the dependencies ‘topGO’, ‘threejs’
#
#
# Installation paths not writeable, unable to update packages
#   path: /shared/ifbstor1/software/miniconda/envs/r-4.0.3/lib/R/library
#   packages:
#     abcrf, ade4, adegenet, admisc, amap, apcluster, ape, argparse, aricode,
#     ashr, babelgene, backports, base64, BAT, batchtools, bayesm, bayestestR,
#     bbmle, bdsmatrix, beanplot, BH, BiasedUrn, BiocManager, bit, blob,
#     bookdown, boot, brew, brio, broom, broom.helpers, bslib, cachem, Cairo,
#     callr, car, carData, caret, changepoint, checkmate, circlize, class,
#     classInt, cli, clipr, clue, cluster, clustermq, codetools, colorspace,
#     colourpicker, commonmark, ComplexUpset, compositions, conquer, countrycode,
#     covr, cpp11, crayon, credentials, curl, dartR, data.table, datawizard, DBI,
#     dbplyr, deldir, dendextend, densityClust, DEoptimR, desc, devtools,
#     dichromat, digest, dismo, doMC, doParallel, doRNG, doSNOW, dplyr, DT,
#     dtplyr, e1071, effectsize, ellipse, evaluate, expm, extrafont, FactoMineR,
#     fansi, farver, fastmap, FD, findpython, fitdistrplus, float, FNN,
#     fontawesome, forcats, foreach, foreign, formatR, Formula, fs, furrr,
#     future, future.apply, gap, gargle, gaston, gdata, gdistance, gdtools,
#     generics, GenSA, geometry, gert, ggbeeswarm, ggdendro, ggfittext, ggforce,
#     ggfun, gggenes, ggiraph, ggplot2, ggpubr, ggraph, ggrepel, ggridges, ggsci,
#     ggsignif, ggvenn, ggVennDiagram, gh, git2r, gitcreds, glmnet, globals, gmm,
#     gmodels, gmp, googledrive, googlesheets4, gower, gplots, graphlayouts,
#     grImport, gt, gtable, gtools, gtsummary, hardhat, HardyWeinberg, haven,
#     heatmaply, hexbin, hierfstat, highr, hitandrun, Hmisc, hms, htmlTable,
#     htmltools, htmlwidgets, httpuv, httr, hwriter, hypervolume, ica, igraph,
#     imputeLCMD, insight, ipred, IRdisplay, IRkernel, irlba, isoband, iterators,
#     jpeg, jsonlite, kernlab, KernSmooth, knitr, kohonen, ks, labdsv, labelled,
#     later, lattice, latticeExtra, lava, learnr, leiden, lgr, LiblineaR,
#     lifecycle, linprog, listenv, lme4, lmtest, lpSolve, lsa, lubridate, magic,
#     MALDIquant, maps, maptools, markdown, MASS, Matrix, MatrixModels,
#     matrixStats, mclust, memoise, memuse, mgcv, mice, minqa, mixKernel, mixsqp,
#     mixtools, mlapi, mnormt, modelr, moments, msigdbr, narray, ncdf4, nleqslv,
#     nlme, nloptr, nls2, NMF, nnet, norm, oompaData, openssl, openxlsx,
#     optparse, packrat, palmerpenguins, parallelDist, parallelly, parameters,
#     parsedate, parsnip, patchwork, pbapply, pbdZMQ, pbmcapply, pdist, pegas,
#     performance, permute, pillar, pingr, pkgbuild, pkgcache, pkgload, pkgmaker,
#     plotly, plyr, png, polyclip, polynom, PopGenReport, pracma, pROC, processx,
#     prodlim, progressr, proj4, proxy, ps, psych, purrr, qap, quantreg,
#     R.devices, R.methodsS3, R.oo, R.utils, ragg, ranger, raster, rbibutils,
#     rcdd, RCircos, RColorBrewer, Rcpp, RcppAnnoy, RcppArmadillo, RcppEigen,
#     RcppHNSW, RcppNumerical, RcppParallel, RCurl, Rdpack, readr, readxl,
#     recipes, renv, repr, reprex, reshape, reticulate, rex, rgdal, rgeos, rgl,
#     RhpcBLASctl, rintrojs, rio, rjags, rJava, rjson, RJSONIO, Rlab, rlang,
#     RMariaDB, rmarkdown, Rmpfr, robustbase, roxygen2, rpart, rpart.plot,
#     rprojroot, rsample, rsparse, RSpectra, RSQLite, rstatix, rstudioapi, rsvg,
#     Rtsne, Rttf2pt1, rversions, rvest, s2, sandwich, sass, scales, scattermore,
#     scatterplot3d, sctransform, segmented, seqinr, seqminer, seriation,
#     sessioninfo, Seurat, SeuratObject, sf, shadowtext, shiny, shinyAce,
#     shinyalert, shinyBS, shinyFiles, shinyjs, shinytest, shinyWidgets, Signac,
#     slam, slider, sm, SnowballC, sourcetools, sp, sparsesvd, spatstat,
#     spatstat.data, spatstat.geom, spatstat.linnet, spatstat.sparse,
#     spatstat.utils, spData, spdep, StatMatch, statmod, stringi, stringr,
#     SuppDists, survey, survival, svglite, sys, systemfonts, terra, testthat,
#     text2vec, TFMPvalue, tibble, tictoc, tidygraph, tidyr, tidyselect,
#     tidyverse, timeDate, tinytex, tm, tmvtnorm, treemap, truncnorm, TSP, TTR,
#     tweenr, tzdb, umap, units, usethis, utf8, uuid, uwot, V8, vcd, vcfR, vctrs,
#     vegan, venn, VennDiagram, VGAM, VIM, vioplot, viridis, viridisLite, vroom,
#     waiter, waldo, webshot, WGCNA, whisker, withr, wk, xfun, xgboost, XML,
#     xml2, xts, yaml, yardstick, yulab.utils, zip, zoo

# %%
#BiocManager::install("pcaExplorer", dependencies = TRUE)

# %%
library("pcaExplorer")
# Out:
# Possible Ensembl SSL connectivity problems detected.
# Please see the 'Connection Troubleshooting' section of the biomaRt vignette
# vignette('accessing_ensembl', package = 'biomaRt')Error in curl::curl_fetch_memory(url, handle = handle) :
#   SSL certificate problem: certificate has expired
#
#
# Welcome to pcaExplorer v2.16.0
#
# If you use pcaExplorer in your work, please cite:
#
# Federico Marini, Harald Binder
# pcaExplorer: an R/Bioconductor package for interacting with RNA-seq principal components
# BMC Bioinformatics, 2019 - https://doi.org/10.1186/s12859-019-2879-1

# %%
BiocManager::install("airway")
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# '?repositories' for details
#
# replacement repositories:
#     CRAN: https://cran.r-project.org
#
#
# Bioconductor version 3.12 (BiocManager 1.30.16), R 4.0.3 (2020-10-10)
#
# Installing package(s) 'airway'
#
# Installation paths not writeable, unable to update packages
#   path: /shared/ifbstor1/software/miniconda/envs/r-4.0.3/lib/R/library
#   packages:
#     abcrf, ade4, adegenet, admisc, amap, apcluster, ape, argparse, aricode,
#     ashr, babelgene, backports, base64, BAT, batchtools, bayesm, bayestestR,
#     bbmle, bdsmatrix, beanplot, BH, BiasedUrn, BiocManager, bit, blob,
#     bookdown, boot, brew, brio, broom, broom.helpers, bslib, cachem, Cairo,
#     callr, car, carData, caret, changepoint, checkmate, circlize, class,
#     classInt, cli, clipr, clue, cluster, clustermq, codetools, colorspace,
#     colourpicker, commonmark, ComplexUpset, compositions, conquer, countrycode,
#     covr, cpp11, crayon, credentials, curl, dartR, data.table, datawizard, DBI,
#     dbplyr, deldir, dendextend, densityClust, DEoptimR, desc, devtools,
#     dichromat, digest, dismo, doMC, doParallel, doRNG, doSNOW, dplyr, DT,
#     dtplyr, e1071, effectsize, ellipse, evaluate, expm, extrafont, FactoMineR,
#     fansi, farver, fastmap, FD, findpython, fitdistrplus, float, FNN,
#     fontawesome, forcats, foreach, foreign, formatR, Formula, fs, furrr,
#     future, future.apply, gap, gargle, gaston, gdata, gdistance, gdtools,
#     generics, GenSA, geometry, gert, ggbeeswarm, ggdendro, ggfittext, ggforce,
#     ggfun, gggenes, ggiraph, ggplot2, ggpubr, ggraph, ggrepel, ggridges, ggsci,
#     ggsignif, ggvenn, ggVennDiagram, gh, git2r, gitcreds, glmnet, globals, gmm,
#     gmodels, gmp, googledrive, googlesheets4, gower, gplots, graphlayouts,
#     grImport, gt, gtable, gtools, gtsummary, hardhat, HardyWeinberg, haven,
#     heatmaply, hexbin, hierfstat, highr, hitandrun, Hmisc, hms, htmlTable,
#     htmltools, htmlwidgets, httpuv, httr, hwriter, hypervolume, ica, igraph,
#     imputeLCMD, insight, ipred, IRdisplay, IRkernel, irlba, isoband, iterators,
#     jpeg, jsonlite, kernlab, KernSmooth, knitr, kohonen, ks, labdsv, labelled,
#     later, lattice, latticeExtra, lava, learnr, leiden, lgr, LiblineaR,
#     lifecycle, linprog, listenv, lme4, lmtest, lpSolve, lsa, lubridate, magic,
#     MALDIquant, maps, maptools, markdown, MASS, Matrix, MatrixModels,
#     matrixStats, mclust, memoise, memuse, mgcv, mice, minqa, mixKernel, mixsqp,
#     mixtools, mlapi, mnormt, modelr, moments, msigdbr, narray, ncdf4, nleqslv,
#     nlme, nloptr, nls2, NMF, nnet, norm, oompaData, openssl, openxlsx,
#     optparse, packrat, palmerpenguins, parallelDist, parallelly, parameters,
#     parsedate, parsnip, patchwork, pbapply, pbdZMQ, pbmcapply, pdist, pegas,
#     performance, permute, pillar, pingr, pkgbuild, pkgcache, pkgload, pkgmaker,
#     plotly, plyr, png, polyclip, polynom, PopGenReport, pracma, pROC, processx,
#     prodlim, progressr, proj4, proxy, ps, psych, purrr, qap, quantreg,
#     R.devices, R.methodsS3, R.oo, R.utils, ragg, ranger, raster, rbibutils,
#     rcdd, RCircos, RColorBrewer, Rcpp, RcppAnnoy, RcppArmadillo, RcppEigen,
#     RcppHNSW, RcppNumerical, RcppParallel, RCurl, Rdpack, readr, readxl,
#     recipes, renv, repr, reprex, reshape, reticulate, rex, rgdal, rgeos, rgl,
#     RhpcBLASctl, rintrojs, rio, rjags, rJava, rjson, RJSONIO, Rlab, rlang,
#     RMariaDB, rmarkdown, Rmpfr, robustbase, roxygen2, rpart, rpart.plot,
#     rprojroot, rsample, rsparse, RSpectra, RSQLite, rstatix, rstudioapi, rsvg,
#     Rtsne, Rttf2pt1, rversions, rvest, s2, sandwich, sass, scales, scattermore,
#     scatterplot3d, sctransform, segmented, seqinr, seqminer, seriation,
#     sessioninfo, Seurat, SeuratObject, sf, shadowtext, shiny, shinyAce,
#     shinyalert, shinyBS, shinyFiles, shinyjs, shinytest, shinyWidgets, Signac,
#     slam, slider, sm, SnowballC, sourcetools, sp, sparsesvd, spatstat,
#     spatstat.data, spatstat.geom, spatstat.linnet, spatstat.sparse,
#     spatstat.utils, spData, spdep, StatMatch, statmod, stringi, stringr,
#     SuppDists, survey, survival, svglite, sys, systemfonts, terra, testthat,
#     text2vec, TFMPvalue, tibble, tictoc, tidygraph, tidyr, tidyselect,
#     tidyverse, timeDate, tinytex, tm, tmvtnorm, treemap, truncnorm, TSP, TTR,
#     tweenr, tzdb, umap, units, usethis, utf8, uuid, uwot, V8, vcd, vcfR, vctrs,
#     vegan, venn, VennDiagram, VGAM, VIM, vioplot, viridis, viridisLite, vroom,
#     waiter, waldo, webshot, WGCNA, whisker, withr, wk, xfun, xgboost, XML,
#     xml2, xts, yaml, yardstick, yulab.utils, zip, zoo

# %%
library("pcaExplorer")
pcaExplorer()
# Out:
# The `name` provided ('sign-out') is deprecated in Font Awesome 5:
# * please consider using 'sign-out-alt' or 'fas fa-sign-out-alt' instead
# * use the `verify_fa = FALSE` to deactivate these messages
#
# The `name` provided ('pencil') is deprecated in Font Awesome 5:
# * please consider using 'pencil-alt' or 'fas fa-pencil-alt' instead
# * use the `verify_fa = FALSE` to deactivate these messages
#
# The `name` provided ('file-text') is deprecated in Font Awesome 5:
# * please consider using 'file-alt' or 'fas fa-file-alt' instead
# * use the `verify_fa = FALSE` to deactivate these messages
#
# The `name` provided ('pencil-square-o') is deprecated in Font Awesome 5:
# * please consider using 'edit' or 'fas fa-edit' instead
# * use the `verify_fa = FALSE` to deactivate these messages
#
# This Font Awesome icon ('institution') does not exist:
# * if providing a custom `html_dependency` these `name` checks can
#   be deactivated with `verify_fa = FALSE`
#
# Loading required package: shiny
#
#
# Listening on http://127.0.0.1:3686
